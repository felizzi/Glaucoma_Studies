# %% [markdown]
# # Glaucoma AI Screening Model - Base Case Analysis (Updated Human Screening Cost)
#
# This notebook sets up and runs the base case cost-effectiveness analysis comparing AI-enhanced vs traditional glaucoma screening.
#
# ---
#
# ## Overview
#
# **Objective**: Evaluate the cost-effectiveness of AI-enhanced glaucoma screening compared to traditional screening (no screening baseline).
#
# **Model Structure**:
# - **Population**: General population aged 61 (median), 55% male
# - **Time Horizon**: 30 years
# - **Perspective**: Healthcare system
# - **Discount Rates**: 3% for costs and 1.5% for QALYs
# - **Iterations**: 5,000 Monte Carlo simulations
#
# **Key Model Features**:
# - Markov model with 5 health states: Mild, Moderate, Severe, Visual Impairment (VI), Dead
# - AI screening with sensitivity/specificity adjustment
# - Accounts for false positives and screening costs
# - Age-specific mortality from Swiss life tables (2023)
#
# **Updated Parameters**:
# - **Human screening cost: €240.20** (updated from €215)

# %% [markdown]
# ## 1. Setup and Imports

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import copy

sys.path.append('../src') 

print("✓ Imports complete")
# Out:
# ✓ Imports complete

# %%
from glaucoma_model.parameters import (
    Parameter,
    GlaucomaParameters
)

from glaucoma_model.model import (
    BaseGlaucomaModel,
    AIGlaucomaModel,
    NonAIGlaucomaModel
)

from glaucoma_model.analysis import *
from glaucoma_model.utils import *

print("✓ Model modules loaded")
# Out:
# Parameter class defined!
# Enhanced GlaucomaParameters class defined with state-specific screening accuracy, mortality odds ratios, and false positive disutility!
# Enhanced models with age-dependent mortality from life tables defined!
# ✓ Model modules loaded

# %% [markdown]
# ## 2. Configuration
#
# Set global parameters for the analysis

# %%
# Analysis parameters
N_ITERATIONS = 5000
YEARS = 30
STARTING_AGE = 61  # Median age
MALE_PROPORTION = 0.55
RANDOM_SEED = 42

# Updated cost parameter
HUMAN_SCREENING_COST = 240.20  # Updated from default €215


# Portuguese utility parameters (multiplicative scaling)
SCALING_FACTOR = 0.8812  # To get Mild = 0.868
PORTUGUESE_UTILITIES = {
    'mild': 0.868,
    'moderate': 0.792,
    'severe': 0.681,
    'vi': 0.559
}

print("=== BASE CASE CONFIGURATION ===")
print(f"Iterations: {N_ITERATIONS:,}")
print(f"Time horizon: {YEARS} years")
print(f"Starting age: {STARTING_AGE} years")
print(f"Male proportion: {MALE_PROPORTION:.0%}")
print(f"Random seed: {RANDOM_SEED}")
print(f"\n** UPDATED PARAMETER **")
print(f"Human screening cost: €{HUMAN_SCREENING_COST:.2f}")

print("=== BASE CASE CONFIGURATION ===")
print(f"Iterations: {N_ITERATIONS:,}")
print(f"Time horizon: {YEARS} years")
print(f"Starting age: {STARTING_AGE} years")
print(f"Male proportion: {MALE_PROPORTION:.0%}")
print(f"Random seed: {RANDOM_SEED}")
print(f"\n** UPDATED PARAMETERS - PORTUGUESE UTILITIES **")
print(f"Scaling factor: {SCALING_FACTOR:.4f}")
print(f"\nUtility values:")
for state, utility in PORTUGUESE_UTILITIES.items():
    print(f"  {state.capitalize()}: {utility:.3f}")
# Out:
# === BASE CASE CONFIGURATION ===
# Iterations: 5,000
# Time horizon: 30 years
# Starting age: 61 years
# Male proportion: 55%
# Random seed: 42
#
# ** UPDATED PARAMETER **
# Human screening cost: €240.20
# === BASE CASE CONFIGURATION ===
# Iterations: 5,000
# Time horizon: 30 years
# Starting age: 61 years
# Male proportion: 55%
# Random seed: 42
#
# ** UPDATED PARAMETERS - PORTUGUESE UTILITIES **
# Scaling factor: 0.8812
#
# Utility values:
#   Mild: 0.868
#   Moderate: 0.792
#   Severe: 0.681
#   Vi: 0.559

# %% [markdown]
# ## 3. Model Initialization
#
# Initialize AI and Non-AI glaucoma models with mortality tables

# %%
# Initialize AI model
model_ai = AIGlaucomaModel(starting_age=STARTING_AGE)
model_ai.load_mortality_table_from_file(
    filepath_male='../data/male_mortality_2023.csv', 
    filepath_female='../data/female_mortality_2023.csv', 
    male_proportion=MALE_PROPORTION
)

# Initialize Non-AI model
model_non_ai = NonAIGlaucomaModel(starting_age=STARTING_AGE)
model_non_ai.load_mortality_table_from_file(
    filepath_male='../data/male_mortality_2023.csv',
    filepath_female='../data/female_mortality_2023.csv',
    male_proportion=MALE_PROPORTION
)

print("✓ Models initialized with mortality tables")
print(f"\nAI Model: {model_ai}")
print(f"Non-AI Model: {model_non_ai}")
# Out:
# Applied Non-AI cost structure: Only VI patients incur costs
# ✓ Models initialized with mortality tables
#
# AI Model: <glaucoma_model.model.AIGlaucomaModel object at 0x000001B28B212090>
# Non-AI Model: <glaucoma_model.model.NonAIGlaucomaModel object at 0x000001B2896D2510>

# %% [markdown]
# ## 3.1 Update Human Screening Cost
#
# Modify the default human screening cost to €240.20

# %%
# Store original cost for reference
original_human_cost = model_ai.params.costs['human_screening'].mean

# Update human screening cost in both models
model_ai.params.costs['human_screening'].mean = HUMAN_SCREENING_COST

print("=== HUMAN SCREENING COST UPDATE ===")
print(f"Original cost: €{original_human_cost:.2f}")
print(f"Updated cost: €{HUMAN_SCREENING_COST:.2f}")
print(f"Change: €{HUMAN_SCREENING_COST - original_human_cost:+.2f}")
print(f"\n✓ Human screening cost updated in both models")
# Out:
# === HUMAN SCREENING COST UPDATE ===
# Original cost: €215.00
# Updated cost: €240.20
# Change: €+25.20
#
# ✓ Human screening cost updated in both models

# %% [markdown]
# ## 3.2 Update Utilities to Portuguese Values
#
# Modify utilities using multiplicative scaling to preserve relative utility decrements

# %%
# Store original utilities for reference
original_utilities = {
    'mild': model_ai.params.utilities['utility_mild'].mean,
    'moderate': model_ai.params.utilities['utility_moderate'].mean,
    'severe': model_ai.params.utilities['utility_severe'].mean,
    'vi': model_ai.params.utilities['utility_vi'].mean
}

# Update utilities in both models
for model in [model_ai, model_non_ai]:
    model.params.utilities['utility_mild'].mean = PORTUGUESE_UTILITIES['mild']
    model.params.utilities['utility_moderate'].mean = PORTUGUESE_UTILITIES['moderate']
    model.params.utilities['utility_severe'].mean = PORTUGUESE_UTILITIES['severe']
    model.params.utilities['utility_vi'].mean = PORTUGUESE_UTILITIES['vi']

print("=== UTILITY UPDATE - PORTUGUESE VALUES ===")
print(f"\nScaling factor applied: {SCALING_FACTOR:.4f}")
print(f"\n{'State':<12} {'Original':<12} {'Portuguese':<12} {'Change':<12} {'Ratio Preserved'}")
print("-" * 70)

for state in ['mild', 'moderate', 'severe', 'vi']:
    orig = original_utilities[state]
    port = PORTUGUESE_UTILITIES[state]
    change = port - orig
    ratio_check = '✓' if abs((port / orig) - SCALING_FACTOR) < 0.001 else '✗'
    print(f"{state.capitalize():<12} {orig:<12.3f} {port:<12.3f} {change:<+12.3f} {ratio_check}")

print("\n" + "="*70)
print("RATIO VERIFICATION (Preserves relative severity):")
print(f"Original moderate/mild: {original_utilities['moderate']/original_utilities['mild']:.3f}")
print(f"Portuguese moderate/mild: {PORTUGUESE_UTILITIES['moderate']/PORTUGUESE_UTILITIES['mild']:.3f}")
print(f"Original severe/mild: {original_utilities['severe']/original_utilities['mild']:.3f}")
print(f"Portuguese severe/mild: {PORTUGUESE_UTILITIES['severe']/PORTUGUESE_UTILITIES['mild']:.3f}")
print("=" * 70)

print("\n✓ Portuguese utilities updated in both models")
# Out:
# === UTILITY UPDATE - PORTUGUESE VALUES ===
#
# Scaling factor applied: 0.8812
#
# State        Original     Portuguese   Change       Ratio Preserved
# ----------------------------------------------------------------------
# Mild         0.985        0.868        -0.117       ✓
# Moderate     0.899        0.792        -0.107       ✓
# Severe       0.773        0.681        -0.092       ✓
# Vi           0.634        0.559        -0.075       ✓
#
# ======================================================================
# RATIO VERIFICATION (Preserves relative severity):
# Original moderate/mild: 0.913
# Portuguese moderate/mild: 0.912
# Original severe/mild: 0.785
# Portuguese severe/mild: 0.785
# ======================================================================
#
# ✓ Portuguese utilities updated in both models

# %% [markdown]
# ## 4. Model Parameters Review
#
# Review key parameters for both models

# %% [markdown]
# ### 4.1 AI Model Parameters

# %%
print("=== AI MODEL PARAMETERS ===")
model_ai.params.get_summary()
# Out:
# === AI MODEL PARAMETERS ===
#                        Category                  Parameter      Mean  \
# 0                         Costs            monitoring_mild   352.000
# 1                         Costs        monitoring_moderate   463.000
# 2                         Costs          monitoring_severe   644.000
# 3                         Costs              monitoring_vi   576.000
# 4                         Costs             treatment_mild   303.000
# 5                         Costs         treatment_moderate   429.000
# 6                         Costs           treatment_severe   609.000
# 7                         Costs               treatment_vi   662.000
# 8                         Costs                 other_mild     0.000
# 9                         Costs             other_moderate     0.000
# 10                        Costs               other_severe     0.000
# 11                        Costs                   other_vi  5520.000
# 12                        Costs          productivity_mild     0.000
# 13                        Costs      productivity_moderate     0.000
# 14                        Costs        productivity_severe     0.000
# 15                        Costs            productivity_vi  7630.000
# 16                        Costs               ai_screening    11.650
# 17                        Costs            human_screening   240.200
# 18                    Utilities               utility_mild     0.868
# 19                    Utilities           utility_moderate     0.792
# 20                    Utilities             utility_severe     0.681
# 21                    Utilities                 utility_vi     0.559
# 22                    Utilities  disutility_false_positive     0.020
# 23                  Transitions           mild_to_moderate     0.058
# 24                  Transitions         moderate_to_severe     0.040
# 25                  Transitions               severe_to_vi     0.032
# 26           Screening_Accuracy         true_positive_rate     0.950
# 27           Screening_Accuracy         true_negative_rate     0.920
# 28           Screening_Accuracy        false_positive_rate     0.080
# 29           Screening_Accuracy        false_negative_rate     0.050
# 30           Screening_Accuracy                sensitivity     0.775
# 31           Screening_Accuracy                specificity     0.954
# 32      Screening_Accuracy_Mild                    tp_mild     0.920
# 33      Screening_Accuracy_Mild                    tn_mild     0.940
# 34      Screening_Accuracy_Mild                    fp_mild     0.060
# 35      Screening_Accuracy_Mild                    fn_mild     0.080
# 36  Screening_Accuracy_Moderate                tp_moderate     0.950
# 37  Screening_Accuracy_Moderate                tn_moderate     0.930
# 38  Screening_Accuracy_Moderate                fp_moderate     0.070
# 39  Screening_Accuracy_Moderate                fn_moderate     0.050
# 40    Screening_Accuracy_Severe                  tp_severe     0.980
# 41    Screening_Accuracy_Severe                  tn_severe     0.910
# 42    Screening_Accuracy_Severe                  fp_severe     0.090
# 43    Screening_Accuracy_Severe                  fn_severe     0.020
# 44             Screening_Params       detection_proportion     1.000
# 45             Screening_Params         prevalence_general     0.050
# 46             Screening_Params              prevalence_dr     0.070
# 47               Discount_Rates              cost_discount     0.030
# 48               Discount_Rates            health_discount     0.015
# 49        Mortality_Odds_Ratios          mortality_or_mild     1.800
# 50        Mortality_Odds_Ratios      mortality_or_moderate     1.800
# 51        Mortality_Odds_Ratios        mortality_or_severe     1.800
# 52        Mortality_Odds_Ratios            mortality_or_vi     3.900
#
#             Std Distribution
# 0     70.400000        gamma
# 1     92.600000        gamma
# 2    128.800000        gamma
# 3    115.200000        gamma
# 4     60.600000        gamma
# 5     85.800000        gamma
# 6    121.800000        gamma
# 7    132.400000        gamma
# 8      0.000000        gamma
# 9      0.000000        gamma
# 10     0.000000        gamma
# 11  1104.000000        gamma
# 12     0.000000        gamma
# 13     0.000000        gamma
# 14     0.000000        gamma
# 15  1526.000000        gamma
# 16     3.000000        gamma
# 17    12.000000        gamma
# 18     0.023000         beta
# 19     0.039000         beta
# 20     0.046000         beta
# 21     0.052000         beta
# 22     0.005000         beta
# 23     0.000303         beta
# 24     0.000253         beta
# 25     0.000230         beta
# 26     0.020000         beta
# 27     0.020000         beta
# 28     0.020000         beta
# 29     0.020000         beta
# 30     0.066000         beta
# 31     0.009000         beta
# 32     0.030000         beta
# 33     0.020000         beta
# 34     0.020000         beta
# 35     0.030000         beta
# 36     0.020000         beta
# 37     0.020000         beta
# 38     0.020000         beta
# 39     0.020000         beta
# 40     0.010000         beta
# 41     0.020000         beta
# 42     0.020000         beta
# 43     0.010000         beta
# 44     0.010000         beta
# 45     0.005000         beta
# 46     0.010000         beta
# 47     0.010000         beta
# 48     0.005000         beta
# 49     0.100000    lognormal
# 50     0.100000    lognormal
# 51     0.100000    lognormal
# 52     0.100000    lognormal

# %% [markdown]
# ### 4.2 Non-AI Model Parameters

# %%
print("=== NON-AI MODEL PARAMETERS ===")
model_non_ai.params.get_summary()
# Out:
# === NON-AI MODEL PARAMETERS ===
#                        Category                  Parameter      Mean  \
# 0                         Costs            monitoring_mild     0.000
# 1                         Costs        monitoring_moderate     0.000
# 2                         Costs          monitoring_severe     0.000
# 3                         Costs              monitoring_vi   576.000
# 4                         Costs             treatment_mild     0.000
# 5                         Costs         treatment_moderate     0.000
# 6                         Costs           treatment_severe     0.000
# 7                         Costs               treatment_vi   662.000
# 8                         Costs                 other_mild     0.000
# 9                         Costs             other_moderate     0.000
# 10                        Costs               other_severe     0.000
# 11                        Costs                   other_vi  5520.000
# 12                        Costs          productivity_mild     0.000
# 13                        Costs      productivity_moderate     0.000
# 14                        Costs        productivity_severe     0.000
# 15                        Costs            productivity_vi  7630.000
# 16                        Costs               ai_screening     0.010
# 17                        Costs            human_screening     0.010
# 18                    Utilities               utility_mild     0.868
# 19                    Utilities           utility_moderate     0.792
# 20                    Utilities             utility_severe     0.681
# 21                    Utilities                 utility_vi     0.559
# 22                    Utilities  disutility_false_positive     0.020
# 23                  Transitions           mild_to_moderate     0.143
# 24                  Transitions         moderate_to_severe     0.087
# 25                  Transitions               severe_to_vi     0.077
# 26           Screening_Accuracy         true_positive_rate     0.750
# 27           Screening_Accuracy         true_negative_rate     0.800
# 28           Screening_Accuracy        false_positive_rate     0.200
# 29           Screening_Accuracy        false_negative_rate     0.250
# 30           Screening_Accuracy                sensitivity     0.775
# 31           Screening_Accuracy                specificity     0.954
# 32      Screening_Accuracy_Mild                    tp_mild     0.700
# 33      Screening_Accuracy_Mild                    tn_mild     0.850
# 34      Screening_Accuracy_Mild                    fp_mild     0.150
# 35      Screening_Accuracy_Mild                    fn_mild     0.300
# 36  Screening_Accuracy_Moderate                tp_moderate     0.780
# 37  Screening_Accuracy_Moderate                tn_moderate     0.820
# 38  Screening_Accuracy_Moderate                fp_moderate     0.180
# 39  Screening_Accuracy_Moderate                fn_moderate     0.220
# 40    Screening_Accuracy_Severe                  tp_severe     0.880
# 41    Screening_Accuracy_Severe                  tn_severe     0.780
# 42    Screening_Accuracy_Severe                  fp_severe     0.220
# 43    Screening_Accuracy_Severe                  fn_severe     0.120
# 44             Screening_Params       detection_proportion     1.000
# 45             Screening_Params         prevalence_general     0.050
# 46             Screening_Params              prevalence_dr     0.070
# 47               Discount_Rates              cost_discount     0.030
# 48               Discount_Rates            health_discount     0.015
# 49        Mortality_Odds_Ratios          mortality_or_mild     1.800
# 50        Mortality_Odds_Ratios      mortality_or_moderate     1.800
# 51        Mortality_Odds_Ratios        mortality_or_severe     1.800
# 52        Mortality_Odds_Ratios            mortality_or_vi     3.900
#
#              Std Distribution
# 0   0.000000e+00        gamma
# 1   0.000000e+00        gamma
# 2   0.000000e+00        gamma
# 3   1.152000e+02        gamma
# 4   0.000000e+00        gamma
# 5   0.000000e+00        gamma
# 6   0.000000e+00        gamma
# 7   1.324000e+02        gamma
# 8   0.000000e+00        gamma
# 9   0.000000e+00        gamma
# 10  0.000000e+00        gamma
# 11  1.104000e+03        gamma
# 12  0.000000e+00        gamma
# 13  0.000000e+00        gamma
# 14  0.000000e+00        gamma
# 15  1.526000e+03        gamma
# 16  1.000000e-04        gamma
# 17  1.000000e-07        gamma
# 18  2.300000e-02         beta
# 19  3.900000e-02         beta
# 20  4.600000e-02         beta
# 21  5.200000e-02         beta
# 22  5.000000e-03         beta
# 23  3.230000e-02         beta
# 24  2.603000e-02         beta
# 25  2.467000e-02         beta
# 26  8.000000e-02         beta
# 27  8.000000e-02         beta
# 28  8.000000e-02         beta
# 29  8.000000e-02         beta
# 30  6.600000e-02         beta
# 31  9.000000e-03         beta
# 32  8.000000e-02         beta
# 33  6.000000e-02         beta
# 34  6.000000e-02         beta
# 35  8.000000e-02         beta
# 36  7.000000e-02         beta
# 37  6.000000e-02         beta
# 38  6.000000e-02         beta
# 39  7.000000e-02         beta
# 40  5.000000e-02         beta
# 41  7.000000e-02         beta
# 42  7.000000e-02         beta
# 43  5.000000e-02         beta
# 44  0.000000e+00         beta
# 45  5.000000e-03         beta
# 46  1.000000e-02         beta
# 47  1.000000e-02         beta
# 48  5.000000e-03         beta
# 49  1.000000e-01    lognormal
# 50  1.000000e-01    lognormal
# 51  1.000000e-01    lognormal
# 52  1.000000e-01    lognormal

# %% [markdown]
# ## 5. Define Initial Distribution
#
# Set the starting distribution of patients across health states

# %%
# Initial distribution: 38 mild, 9 moderate, 7 severe, 0 VI, 0 dead
# Based on the prevalence of glaucoma states in the general population
initial_dist = [38, 9, 7, 0, 0]
initial_dist = np.array(initial_dist) / np.sum(initial_dist)

print("=== INITIAL DISTRIBUTION ===")
print(f"Mild:     {initial_dist[0]:.2%}")
print(f"Moderate: {initial_dist[1]:.2%}")
print(f"Severe:   {initial_dist[2]:.2%}")
print(f"VI:       {initial_dist[3]:.2%}")
print(f"Dead:     {initial_dist[4]:.2%}")
print(f"\nTotal:    {np.sum(initial_dist):.2%}")
# Out:
# === INITIAL DISTRIBUTION ===
# Mild:     70.37%
# Moderate: 16.67%
# Severe:   12.96%
# VI:       0.00%
# Dead:     0.00%
#
# Total:    100.00%

# %% [markdown]
# ## 6. Run Probabilistic Sensitivity Analysis (PSA)
#
# Run Monte Carlo simulations for both AI and Non-AI models

# %% [markdown]
# ### 6.1 AI Model PSA

# %%
print(f"Running AI Model PSA with {N_ITERATIONS:,} iterations...")

ai_psa_results = model_ai.run_probabilistic(
    n_iterations=N_ITERATIONS,
    initial_dist=initial_dist,
    years=YEARS,
    include_screening=True,
    population_type='general',
    random_seed=RANDOM_SEED,
    return_traces=True
)

print("✓ AI Model PSA complete")
print(f"\nTrace tensor shape: {ai_psa_results['trace_tensor'].shape}")
print(f"Variables tracked: {len(ai_psa_results['trace_variable_names'])}")
# Out:
# Running AI Model PSA with 5,000 iterations...
# Running 5000 PSA iterations for AI Enhanced Model (Starting Age: 61)...
#   AI Model Iteration 100/5000
#   AI Model Iteration 200/5000
#   AI Model Iteration 300/5000
#   AI Model Iteration 400/5000
#   AI Model Iteration 500/5000
#   AI Model Iteration 600/5000
#   AI Model Iteration 700/5000
#   AI Model Iteration 800/5000
#   AI Model Iteration 900/5000
#   AI Model Iteration 1000/5000
#   AI Model Iteration 1100/5000
#   AI Model Iteration 1200/5000
#   AI Model Iteration 1300/5000
#   AI Model Iteration 1400/5000
#   AI Model Iteration 1500/5000
#   AI Model Iteration 1600/5000
#   AI Model Iteration 1700/5000
#   AI Model Iteration 1800/5000
#   AI Model Iteration 1900/5000
#   AI Model Iteration 2000/5000
#   AI Model Iteration 2100/5000
#   AI Model Iteration 2200/5000
#   AI Model Iteration 2300/5000
#   AI Model Iteration 2400/5000
#   AI Model Iteration 2500/5000
#   AI Model Iteration 2600/5000
#   AI Model Iteration 2700/5000
#   AI Model Iteration 2800/5000
#   AI Model Iteration 2900/5000
#   AI Model Iteration 3000/5000
#   AI Model Iteration 3100/5000
#   AI Model Iteration 3200/5000
#   AI Model Iteration 3300/5000
#   AI Model Iteration 3400/5000
#   AI Model Iteration 3500/5000
#   AI Model Iteration 3600/5000
#   AI Model Iteration 3700/5000
#   AI Model Iteration 3800/5000
#   AI Model Iteration 3900/5000
#   AI Model Iteration 4000/5000
#   AI Model Iteration 4100/5000
#   AI Model Iteration 4200/5000
#   AI Model Iteration 4300/5000
#   AI Model Iteration 4400/5000
#   AI Model Iteration 4500/5000
#   AI Model Iteration 4600/5000
#   AI Model Iteration 4700/5000
#   AI Model Iteration 4800/5000
#   AI Model Iteration 4900/5000
#   AI Model Iteration 5000/5000
# ✓ AI Model PSA complete
#
# Trace tensor shape: (5000, 31, 28)
# Variables tracked: 28

# %%
original_vi_proportion = ai_psa_results['trace_tensor'][:, :, trace_variable_names.index('Prop_VI')].mean(axis=0)
print(original_vi_proportion[-1])  # Final year
# Out:
# 0.007883455072215807

# %%
# Test 1: Original utilities
np.random.seed(42)
model_ai_1 = AIGlaucomaModel(starting_age=61)
print("Random state after init 1:", np.random.get_state()[1][0:5])
ai_psa_1 = model_ai_1.run_probabilistic(
    n_iterations=10,
    initial_dist=initial_dist,
    years=YEARS,
    include_screening=True,
    population_type='general',
    random_seed=RANDOM_SEED,
    return_traces=True)
print("VI prop:", ai_psa_1['trace_tensor'][:, -1, trace_variable_names.index('Prop_VI')].mean())
# Out:
# Random state after init 1: [        42 3107752595 1895908407 3900362577 3030691166]
# Running 10 PSA iterations for AI Enhanced Model (Starting Age: 61)...
# VI prop: 0.005875942900645773

# %% [markdown]
# ### 6.2 Non-AI Model PSA

# %%
print(f"Running Non-AI Model PSA with {N_ITERATIONS:,} iterations...")

non_ai_psa_results = model_non_ai.run_probabilistic(
    n_iterations=N_ITERATIONS,
    initial_dist=initial_dist,
    years=YEARS,
    include_screening=True,
    population_type='general',
    random_seed=RANDOM_SEED,
    return_traces=True
)

print("✓ Non-AI Model PSA complete")
print(f"\nTrace tensor shape: {non_ai_psa_results['trace_tensor'].shape}")
print(f"Variables tracked: {len(non_ai_psa_results['trace_variable_names'])}")
# Out:
# Running Non-AI Model PSA with 5,000 iterations...
# Running 5000 PSA iterations for Traditional Non-AI Model (Starting Age: 61)...
#   Non-AI Model Iteration 100/5000
#   Non-AI Model Iteration 200/5000
#   Non-AI Model Iteration 300/5000
#   Non-AI Model Iteration 400/5000
#   Non-AI Model Iteration 500/5000
#   Non-AI Model Iteration 600/5000
#   Non-AI Model Iteration 700/5000
#   Non-AI Model Iteration 800/5000
#   Non-AI Model Iteration 900/5000
#   Non-AI Model Iteration 1000/5000
#   Non-AI Model Iteration 1100/5000
#   Non-AI Model Iteration 1200/5000
#   Non-AI Model Iteration 1300/5000
#   Non-AI Model Iteration 1400/5000
#   Non-AI Model Iteration 1500/5000
#   Non-AI Model Iteration 1600/5000
#   Non-AI Model Iteration 1700/5000
#   Non-AI Model Iteration 1800/5000
#   Non-AI Model Iteration 1900/5000
#   Non-AI Model Iteration 2000/5000
#   Non-AI Model Iteration 2100/5000
#   Non-AI Model Iteration 2200/5000
#   Non-AI Model Iteration 2300/5000
#   Non-AI Model Iteration 2400/5000
#   Non-AI Model Iteration 2500/5000
#   Non-AI Model Iteration 2600/5000
#   Non-AI Model Iteration 2700/5000
#   Non-AI Model Iteration 2800/5000
#   Non-AI Model Iteration 2900/5000
#   Non-AI Model Iteration 3000/5000
#   Non-AI Model Iteration 3100/5000
#   Non-AI Model Iteration 3200/5000
#   Non-AI Model Iteration 3300/5000
#   Non-AI Model Iteration 3400/5000
#   Non-AI Model Iteration 3500/5000
#   Non-AI Model Iteration 3600/5000
#   Non-AI Model Iteration 3700/5000
#   Non-AI Model Iteration 3800/5000
#   Non-AI Model Iteration 3900/5000
#   Non-AI Model Iteration 4000/5000
#   Non-AI Model Iteration 4100/5000
#   Non-AI Model Iteration 4200/5000
#   Non-AI Model Iteration 4300/5000
#   Non-AI Model Iteration 4400/5000
#   Non-AI Model Iteration 4500/5000
#   Non-AI Model Iteration 4600/5000
#   Non-AI Model Iteration 4700/5000
#   Non-AI Model Iteration 4800/5000
#   Non-AI Model Iteration 4900/5000
#   Non-AI Model Iteration 5000/5000
# ✓ Non-AI Model PSA complete
#
# Trace tensor shape: (5000, 31, 28)
# Variables tracked: 28

# %% [markdown]
# ## 7. Adjust for AI Screening Sensitivity and Specificity
#
# Account for imperfect sensitivity and specificity of AI screening by blending AI and Non-AI results

# %%
print("Adjusting AI results for sensitivity and specificity...")

# Get trace tensors and variable names
ai_traces = ai_psa_results['trace_tensor']
non_ai_traces = non_ai_psa_results['trace_tensor']
trace_variable_names = ai_psa_results['trace_variable_names']

# Create adjusted AI results
ai_eff0_psa_traces = copy.deepcopy(ai_traces)
ai_eff0_psa_results = copy.deepcopy(ai_psa_results)

# Get sensitivity value
sensitivity_value = model_ai.params.screening_accuracy['sensitivity'].mean
specificity_value = model_ai.params.screening_accuracy['specificity'].mean

print(f"\nScreening Performance:")
print(f"  Sensitivity: {sensitivity_value:.1%}")
print(f"  Specificity: {specificity_value:.1%}")

# Adjust costs: weighted average based on sensitivity
print("\nAdjusting costs...")
for var_name in ['Total_Cost', 'Total_Cost_Disc']:
    if var_name in trace_variable_names:
        var_idx = trace_variable_names.index(var_name)
        ai_eff0_psa_traces[:, :, var_idx] = (
            sensitivity_value * ai_traces[:, :, var_idx] +
            (1 - sensitivity_value) * non_ai_traces[:, :, var_idx]
        )

# Adjust QALYs: weighted average based on sensitivity
print("Adjusting QALYs...")
qaly_vars = ['Total_QALY', 'Total_QALY_Disc', 'QALY_Mild', 'QALY_Moderate', 'QALY_Severe', 'QALY_VI']
for var_name in qaly_vars:
    if var_name in trace_variable_names:
        var_idx = trace_variable_names.index(var_name)
        ai_eff0_psa_traces[:, :, var_idx] = (
            sensitivity_value * ai_traces[:, :, var_idx] +
            (1 - sensitivity_value) * non_ai_traces[:, :, var_idx]
        )

ai_eff0_psa_results['trace_tensor'] = ai_eff0_psa_traces

print("✓ Sensitivity/specificity adjustment complete")
# Out:
# Adjusting AI results for sensitivity and specificity...
#
# Screening Performance:
#   Sensitivity: 77.5%
#   Specificity: 95.4%
#
# Adjusting costs...
# Adjusting QALYs...
# ✓ Sensitivity/specificity adjustment complete

# %% [markdown]
# ## 8. Add Screening Costs
#
# Add AI screening costs and false positive follow-up costs at year 0
#
# **Note**: False positive follow-ups use the updated human screening cost of €240.20

# %%
print("Adding screening costs...")

# Get cost indices
idx_cost = trace_variable_names.index('Total_Cost')
idx_cost_disc = trace_variable_names.index('Total_Cost_Disc')

# Get parameters
prevalence = model_ai.params.screening_params['prevalence_general'].mean
ai_screening_cost = model_ai.params.costs['ai_screening'].mean
human_screening_cost = model_ai.params.costs['human_screening'].mean

print(f"\nScreening Parameters:")
print(f"  Prevalence: {prevalence:.2%}")
print(f"  AI screening cost: €{ai_screening_cost:,.2f}")
print(f"  Human screening cost (for FPs): €{human_screening_cost:,.2f}")

# Calculate per-case costs
ai_screening_per_case = (1/prevalence) * ai_screening_cost
false_positives_per_case = ((1 - prevalence) / prevalence) * (1 - specificity_value)
fp_cost_per_case = false_positives_per_case * human_screening_cost
total_screening_cost = ai_screening_per_case + fp_cost_per_case

print(f"\nPer-Case Screening Costs:")
print(f"  AI screening: €{ai_screening_per_case:,.2f}")
print(f"  False positive rate: {false_positives_per_case:.2%}")
print(f"  False positive cost: €{fp_cost_per_case:,.2f}")
print(f"  Total screening cost: €{total_screening_cost:,.2f}")

# Add screening costs at year 0
ai_eff0_psa_results['trace_tensor'][:, 0, idx_cost] += total_screening_cost
ai_eff0_psa_results['trace_tensor'][:, 0, idx_cost_disc] += total_screening_cost

print("\n✓ Screening costs added to year 0")
# Out:
# Adding screening costs...
#
# Screening Parameters:
#   Prevalence: 5.00%
#   AI screening cost: €11.65
#   Human screening cost (for FPs): €240.20
#
# Per-Case Screening Costs:
#   AI screening: €233.00
#   False positive rate: 87.40%
#   False positive cost: €209.93
#   Total screening cost: €442.93
#
# ✓ Screening costs added to year 0

# %% [markdown]
# ## 9. Trace Analysis
#
# Calculate mean traces across all iterations for visualization

# %%
# Calculate mean traces
mean_traces_ai = np.mean(ai_eff0_psa_results['trace_tensor'], axis=0)
mean_traces_non_ai = np.mean(non_ai_psa_results['trace_tensor'], axis=0)

# Convert to DataFrames for easy access
mean_traces_df_ai = pd.DataFrame(
    mean_traces_ai,
    columns=trace_variable_names
)

mean_traces_df_non_ai = pd.DataFrame(
    mean_traces_non_ai,
    columns=trace_variable_names
)

print("✓ Mean traces calculated")
print(f"\nAvailable variables: {', '.join(trace_variable_names)}")
# Out:
# ✓ Mean traces calculated
#
# Available variables: Year, Age, Prop_Mild, Prop_Moderate, Prop_Severe, Prop_VI, Prop_Dead, Prop_Alive, Total_Cost, Total_QALY, Total_Cost_Disc, Total_QALY_Disc, Screening_Cost, Cost_Mild, Cost_Moderate, Cost_Severe, Cost_VI, QALY_Mild, QALY_Moderate, QALY_Severe, QALY_VI, Cost_Discount_Factor, Health_Discount_Factor, Mortality_Rate_Mild, Mortality_Rate_Moderate, Mortality_Rate_Severe, Mortality_Rate_VI, Base_Mortality_qx

# %% [markdown]
# ## 10. Visualizations
#
# Visualize key outcomes over time

# %% [markdown]
# ### 10.1 Cost Trajectories

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: Total costs comparison
years_axis = range(YEARS + 1)
ax1.plot(years_axis, mean_traces_df_ai['Total_Cost'], label='AI Screening', linewidth=2, color='#3498db')
ax1.plot(years_axis, mean_traces_df_non_ai['Total_Cost'], label='No Screening', linewidth=2, color='#e74c3c')
ax1.set_xlabel('Year', fontsize=12)
ax1.set_ylabel('Cumulative Cost (€)', fontsize=12)
ax1.set_title('Total Costs Over Time', fontsize=14, fontweight='bold')
ax1.legend(fontsize=11)
ax1.grid(alpha=0.3)

# Plot 2: Incremental costs
incremental_costs = mean_traces_df_ai['Total_Cost'] - mean_traces_df_non_ai['Total_Cost']
ax2.plot(years_axis, incremental_costs, linewidth=2, color='#2ecc71')
ax2.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
ax2.set_xlabel('Year', fontsize=12)
ax2.set_ylabel('Incremental Cost (€)', fontsize=12)
ax2.set_title('Incremental Costs (AI vs No Screening)', fontsize=14, fontweight='bold')
ax2.grid(alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\nFinal incremental cost: €{incremental_costs.iloc[-1]:,.0f}")
# Out:
# Final incremental cost: €-119

# %% [markdown]
# ### 10.2 QALY Trajectories

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: Total QALYs comparison
ax1.plot(years_axis, mean_traces_df_ai['Total_QALY'], label='AI Screening', linewidth=2, color='#3498db')
ax1.plot(years_axis, mean_traces_df_non_ai['Total_QALY'], label='No Screening', linewidth=2, color='#e74c3c')
ax1.set_xlabel('Year', fontsize=12)
ax1.set_ylabel('Cumulative QALYs', fontsize=12)
ax1.set_title('Total QALYs Over Time', fontsize=14, fontweight='bold')
ax1.legend(fontsize=11)
ax1.grid(alpha=0.3)

# Plot 2: Incremental QALYs
incremental_qalys = mean_traces_df_ai['Total_QALY'] - mean_traces_df_non_ai['Total_QALY']
ax2.plot(years_axis, incremental_qalys, linewidth=2, color='#9b59b6')
ax2.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
ax2.set_xlabel('Year', fontsize=12)
ax2.set_ylabel('Incremental QALYs', fontsize=12)
ax2.set_title('Incremental QALYs (AI vs No Screening)', fontsize=14, fontweight='bold')
ax2.grid(alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\nFinal incremental QALYs: {incremental_qalys.iloc[-1]:.4f}")
# Out:
# Final incremental QALYs: 0.0205

# %% [markdown]
# ### 10.3 Health State Distribution Over Time

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# AI model health states
health_states = ['Mild', 'Moderate', 'Severe', 'VI']
ax1.stackplot(
    years_axis,
    mean_traces_df_ai['Prop_Mild'],
    mean_traces_df_ai['Prop_Moderate'],
    mean_traces_df_ai['Prop_Severe'],
    mean_traces_df_ai['Prop_VI'],
    labels=health_states,
    alpha=0.8
)
ax1.set_xlabel('Year', fontsize=12)
ax1.set_ylabel('Proportion', fontsize=12)
ax1.set_title('Health State Distribution - AI Screening', fontsize=14, fontweight='bold')
ax1.legend(loc='upper right', fontsize=11)
ax1.set_ylim(0, 1)
ax1.grid(alpha=0.3)

# Non-AI model health states
ax2.stackplot(
    years_axis,
    mean_traces_df_non_ai['Prop_Mild'],
    mean_traces_df_non_ai['Prop_Moderate'],
    mean_traces_df_non_ai['Prop_Severe'],
    mean_traces_df_non_ai['Prop_VI'],
    labels=health_states,
    alpha=0.8
)
ax2.set_xlabel('Year', fontsize=12)
ax2.set_ylabel('Proportion', fontsize=12)
ax2.set_title('Health State Distribution - No Screening', fontsize=14, fontweight='bold')
ax2.legend(loc='upper right', fontsize=11)
ax2.set_ylim(0, 1)
ax2.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Cost-Effectiveness Analysis
#
# Calculate ICERs and cost-effectiveness probabilities across multiple time horizons

# %%
print("Running comprehensive cost-effectiveness analysis...")

comprehensive_results = comprehensive_cost_effectiveness_analysis(
    ai_eff0_psa_results,
    non_ai_psa_results,
    time_horizons=[5, 10, 15, 20, 30],
    thresholds=[0, 20000, 50000, 75000, 100000, 150000, 200000],
    confidence_level=0.95,
    discounted=True
)

print("✓ Cost-effectiveness analysis complete")
# Out:
# Running comprehensive cost-effectiveness analysis...
# Analyzing 5-year time horizon...
# >>> USING NEW VERSION WITH LOOP <<<
# Number of ICERs after filtering: 4902 out of 5000
# Mean ICER: 3018.58
# Analyzing 10-year time horizon...
# >>> USING NEW VERSION WITH LOOP <<<
# Number of ICERs after filtering: 4927 out of 5000
# Mean ICER: -3622.79
# Analyzing 15-year time horizon...
# >>> USING NEW VERSION WITH LOOP <<<
# Number of ICERs after filtering: 4928 out of 5000
# Mean ICER: -8351.34
# Analyzing 20-year time horizon...
# >>> USING NEW VERSION WITH LOOP <<<
# Number of ICERs after filtering: 4928 out of 5000
# Mean ICER: -9743.62
# Analyzing 30-year time horizon...
# >>> USING NEW VERSION WITH LOOP <<<
# Number of ICERs after filtering: 4929 out of 5000
# Mean ICER: -11405.60
# ✓ Cost-effectiveness analysis complete

# %% [markdown]
# ## 12. Results Summary
#
# Generate comprehensive summary table

# %%
summary_table = create_summary_table(comprehensive_results)

print("\n" + "="*100)
print("BASE CASE RESULTS SUMMARY (Human Screening Cost = €240.20)")
print("="*100)
print(summary_table.to_string(index=False))

# Display as DataFrame
display(summary_table)
# Out:
# ====================================================================================================
# BASE CASE RESULTS SUMMARY (Human Screening Cost = €240.20)
# ====================================================================================================
# Time_Horizon Incremental_Cost_Mean Incremental_Cost_95CI Incremental_QALY_Mean Incremental_QALY_95CI     ICER ICER_Mean ICER_Median             ICER_95CI Prob_CE_20k Prob_CE_50k Prob_CE_100k
#      5 years                  €864     [€-1,799, €3,633]                 0.066       [-0.185, 0.321]  €13,109    €3,019      €1,469 [€-142,373, €158,228]       64.5%       75.8%        80.2%
#     10 years               €-1,197     [€-7,518, €4,964]                 0.205       [-0.334, 0.743]  €-5,838   €-3,623     €-3,819 [€-112,259, €112,072]       82.6%       87.1%        88.6%
#     15 years               €-4,838    [€-15,564, €5,480]                 0.386       [-0.501, 1.248] €-12,542   €-8,351     €-7,292  [€-126,839, €94,721]       90.8%       93.0%        93.5%
#     20 years               €-8,492    [€-23,342, €5,503]                 0.583       [-0.638, 1.760] €-14,577   €-9,744     €-8,927 [€-123,209, €105,800]       94.2%       95.4%        95.7%
#     30 years              €-11,346    [€-29,302, €5,790]                 0.863       [-0.716, 2.339] €-13,146  €-11,406     €-9,450  [€-107,342, €83,288]       95.9%       96.7%        96.8%
#   Time_Horizon Incremental_Cost_Mean Incremental_Cost_95CI  \
# 0      5 years                  €864     [€-1,799, €3,633]
# 1     10 years               €-1,197     [€-7,518, €4,964]
# 2     15 years               €-4,838    [€-15,564, €5,480]
# 3     20 years               €-8,492    [€-23,342, €5,503]
# 4     30 years              €-11,346    [€-29,302, €5,790]
#
#   Incremental_QALY_Mean Incremental_QALY_95CI      ICER ICER_Mean ICER_Median  \
# 0                 0.066       [-0.185, 0.321]   €13,109    €3,019      €1,469
# 1                 0.205       [-0.334, 0.743]   €-5,838   €-3,623     €-3,819
# 2                 0.386       [-0.501, 1.248]  €-12,542   €-8,351     €-7,292
# 3                 0.583       [-0.638, 1.760]  €-14,577   €-9,744     €-8,927
# 4                 0.863       [-0.716, 2.339]  €-13,146  €-11,406     €-9,450
#
#                ICER_95CI Prob_CE_20k Prob_CE_50k Prob_CE_100k
# 0  [€-142,373, €158,228]       64.5%       75.8%        80.2%
# 1  [€-112,259, €112,072]       82.6%       87.1%        88.6%
# 2   [€-126,839, €94,721]       90.8%       93.0%        93.5%
# 3  [€-123,209, €105,800]       94.2%       95.4%        95.7%
# 4   [€-107,342, €83,288]       95.9%       96.7%        96.8%

# %% [markdown]
# ## 13. Key Findings
#
# Highlight important results for different time horizons

# %%
print("\n" + "="*100)
print("KEY FINDINGS")
print("="*100)

for horizon in [5, 10, 30]:
    results = comprehensive_results[f'{horizon}_years']['summary']
    
    print(f"\n{'='*50}")
    print(f"{horizon}-YEAR RESULTS")
    print(f"{'='*50}")
    print(f"ICER: €{results['icer_mean']:,.0f}/QALY")
    print(f"  95% CI: [€{results['icer_ci'][0]:,.0f}, €{results['icer_ci'][1]:,.0f}]")
    print(f"\nIncremental Cost: €{results['incremental_cost_mean']:,.0f}")
    print(f"  95% CI: [€{results['incremental_cost_ci'][0]:,.0f}, €{results['incremental_cost_ci'][1]:,.0f}]")
    print(f"\nIncremental QALYs: {results['incremental_qaly_mean']:.4f}")
    print(f"  95% CI: [{results['incremental_qaly_ci'][0]:.4f}, {results['incremental_qaly_ci'][1]:.4f}]")
    print(f"\nProbability Cost-Effective:")
    print(f"  At €20,000/QALY: {results['prob_cost_effective_20k']:.1f}%")
    print(f"  At €50,000/QALY: {results['prob_cost_effective_50k']:.1f}%")
    print(f"  At €100,000/QALY: {results['prob_cost_effective_100k']:.1f}%")
# Out:
# ====================================================================================================
# KEY FINDINGS
# ====================================================================================================
#
# ==================================================
# 5-YEAR RESULTS
# ==================================================
# ICER: €3,019/QALY
#   95% CI: [€-142,373, €158,228]
#
# Incremental Cost: €864
#   95% CI: [€-1,799, €3,633]
#
# Incremental QALYs: 0.0659
#   95% CI: [-0.1847, 0.3207]
#
# Probability Cost-Effective:
#   At €20,000/QALY: 64.5%
#   At €50,000/QALY: 75.8%
#   At €100,000/QALY: 80.2%
#
# ==================================================
# 10-YEAR RESULTS
# ==================================================
# ICER: €-3,623/QALY
#   95% CI: [€-112,259, €112,072]
#
# Incremental Cost: €-1,197
#   95% CI: [€-7,518, €4,964]
#
# Incremental QALYs: 0.2050
#   95% CI: [-0.3335, 0.7432]
#
# Probability Cost-Effective:
#   At €20,000/QALY: 82.6%
#   At €50,000/QALY: 87.1%
#   At €100,000/QALY: 88.6%
#
# ==================================================
# 30-YEAR RESULTS
# ==================================================
# ICER: €-11,406/QALY
#   95% CI: [€-107,342, €83,288]
#
# Incremental Cost: €-11,346
#   95% CI: [€-29,302, €5,790]
#
# Incremental QALYs: 0.8630
#   95% CI: [-0.7158, 2.3392]
#
# Probability Cost-Effective:
#   At €20,000/QALY: 95.9%
#   At €50,000/QALY: 96.7%
#   At €100,000/QALY: 96.8%

# %% [markdown]
# ## 14. Cost-Effectiveness Plane

# %%
# Get 10-year results for CE plane
results_10y = comprehensive_results['10_years']
inc_costs = results_10y['icer_analysis']['incremental_costs']
inc_qalys = results_10y['icer_analysis']['incremental_qalys']

fig, ax = plt.subplots(figsize=(10, 8))

# Scatter plot
ax.scatter(inc_qalys, inc_costs, alpha=0.3, s=20, color='#3498db')

# Add mean point
mean_qaly = results_10y['summary']['incremental_qaly_mean']
mean_cost = results_10y['summary']['incremental_cost_mean']
ax.scatter(mean_qaly, mean_cost, s=200, color='red', marker='*', 
           label=f'Mean: €{mean_cost:,.0f}, {mean_qaly:.3f} QALYs', zorder=5)

# Add WTP threshold lines
qaly_range = np.array([0, max(inc_qalys)])
ax.plot(qaly_range, 50000 * qaly_range, 'r--', linewidth=2, alpha=0.5, label='€50k/QALY threshold')
ax.plot(qaly_range, 100000 * qaly_range, 'g--', linewidth=2, alpha=0.5, label='€100k/QALY threshold')

# Format plot
ax.axhline(y=0, color='black', linewidth=0.8)
ax.axvline(x=0, color='black', linewidth=0.8)
ax.set_xlabel('Incremental QALYs', fontsize=12)
ax.set_ylabel('Incremental Costs (€)', fontsize=12)
ax.set_title('Cost-Effectiveness Plane (10-Year Horizon)', fontsize=14, fontweight='bold')
ax.legend(fontsize=10)
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 15. Cost-Effectiveness Acceptability Curve

# %%
def calculate_ceac(incremental_costs, incremental_qalys, wtp_thresholds):
    """
    Calculate cost-effectiveness acceptability curve with strict and relaxed definitions
    
    Parameters:
    -----------
    incremental_costs : array
        Array of incremental costs from PSA
    incremental_qalys : array
        Array of incremental QALYs from PSA
    wtp_thresholds : array
        Array of willingness-to-pay thresholds to evaluate
    
    Returns:
    --------
    dict with 'thresholds', 'probabilities_strict', and 'probabilities_relaxed'
    """
    probabilities_strict = []
    probabilities_relaxed = []
    
    for wtp in wtp_thresholds:
        # Identify different scenarios
        dominates = (incremental_costs < 0) & (incremental_qalys > 0)
        saves_money = incremental_costs < 0
        cost_effective_positive = (incremental_costs > 0) & (incremental_qalys > 0) & \
                                 ((incremental_costs / incremental_qalys) <= wtp)
        
        # Strict: Only if QALY gain (dominates OR acceptable ICER with positive QALYs)
        cost_effective_strict = dominates | cost_effective_positive
        prob_strict = np.sum(cost_effective_strict) / len(cost_effective_strict) * 100
        probabilities_strict.append(prob_strict)
        
        # Relaxed: Include cost savings even without QALY gain
        cost_effective_relaxed = saves_money | cost_effective_positive
        prob_relaxed = np.sum(cost_effective_relaxed) / len(cost_effective_relaxed) * 100
        probabilities_relaxed.append(prob_relaxed)
    
    return {
        'thresholds': wtp_thresholds,
        'probabilities_strict': probabilities_strict,
        'probabilities_relaxed': probabilities_relaxed
    }

# Use it:
results_10y = comprehensive_results['10_years']
inc_costs = results_10y['icer_analysis']['incremental_costs']
inc_qalys = results_10y['icer_analysis']['incremental_qalys']

wtp_thresholds = np.arange(0, 200001, 5000)
ceac_data = calculate_ceac(inc_costs, inc_qalys, wtp_thresholds)

# Enhanced plot with both curves
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(ceac_data['thresholds'], ceac_data['probabilities_strict'], 
        linewidth=2.5, color='#2ecc71', label='Strict (QALY gain required)')
ax.plot(ceac_data['thresholds'], ceac_data['probabilities_relaxed'], 
        linewidth=2.5, color='#3498db', linestyle='--', label='Relaxed (includes cost savings)')

# Add reference lines
ax.axhline(y=50, color='gray', linestyle='--', linewidth=1, alpha=0.5, label='50% probability')
ax.axvline(x=20000, color='purple', linestyle='--', linewidth=1, alpha=0.5, label='€20k/QALY')
ax.axvline(x=50000, color='red', linestyle='--', linewidth=1, alpha=0.5, label='€50k/QALY')
ax.axvline(x=100000, color='orange', linestyle='--', linewidth=1, alpha=0.5, label='€100k/QALY')

ax.set_xlabel('Willingness-to-Pay Threshold (€/QALY)', fontsize=12)
ax.set_ylabel('Probability Cost-Effective (%)', fontsize=12)
ax.set_title('Cost-Effectiveness Acceptability Curve (10-Year Horizon)', 
             fontsize=14, fontweight='bold')
ax.set_ylim(0, 100)
ax.legend(fontsize=10, loc='lower right')
ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig('../data/ceac_10_years.png', dpi=300, bbox_inches='tight')
plt.show()

# Print probabilities at key thresholds
print("\n=== Probability of Cost-Effectiveness at Key Thresholds ===")
for threshold in [20000, 50000, 100000]:
    idx = np.argmin(np.abs(wtp_thresholds - threshold))
    prob_strict = ceac_data['probabilities_strict'][idx]
    prob_relaxed = ceac_data['probabilities_relaxed'][idx]
    print(f"At €{threshold:,}/QALY:")
    print(f"  Strict (QALY gain required): {prob_strict:.1f}%")
    print(f"  Relaxed (includes cost savings): {prob_relaxed:.1f}%")
# Out:
# === Probability of Cost-Effectiveness at Key Thresholds ===
# At €20,000/QALY:
#   Strict (QALY gain required): 71.0%
#   Relaxed (includes cost savings): 83.2%
# At €50,000/QALY:
#   Strict (QALY gain required): 75.6%
#   Relaxed (includes cost savings): 87.8%
# At €100,000/QALY:
#   Strict (QALY gain required): 77.0%
#   Relaxed (includes cost savings): 89.2%

# %% [markdown]
# ## 16. Save Results
#
# Save summary table and key results to files

# %%
# Save summary table
summary_table.to_csv('../data/base_case_human_cost_Portugal_summary.csv', index=False)
print("✓ Summary table saved to ../data/base_case_human_cost_Portugal_summary.csv")

# Save detailed results
import pickle
with open('../data/base_case_human_cost_Portugal_comprehensive_results.pkl', 'wb') as f:
    pickle.dump(comprehensive_results, f)
print("✓ Comprehensive results saved to ../data/base_case_human_cost_Portugal_comprehensive_results.pkl")

# Save trace data
mean_traces_df_ai.to_csv('../data/base_case_human_cost_Portugal_traces_ai.csv', index=False)
mean_traces_df_non_ai.to_csv('../data/base_case_human_cost_Portugal_traces_non_ai.csv', index=False)
print("✓ Trace data saved")
# Out:
# ✓ Summary table saved to ../data/base_case_human_cost_Portugal_summary.csv
# ✓ Comprehensive results saved to ../data/base_case_human_cost_Portugal_comprehensive_results.pkl
# ✓ Trace data saved

# %% [markdown]
# ## 17. Save Base Case for Sensitivity Analyses
#
# Save the base case results and parameters for use in sensitivity analyses

# %%
from pathlib import Path
import pickle

# Extract model parameters as dictionary
print("Extracting model parameters...")

model_params_dict = {
    'costs': model_ai.params.costs,
    'utilities': model_ai.params.utilities,
    'transitions': model_ai.params.transitions,
    'screening_accuracy': model_ai.params.screening_accuracy,
    'screening_params': model_ai.params.screening_params,
    'discount_rates': model_ai.params.discount_rates
}

# Get the base case prevalence
original_prevalence = model_ai.params.screening_params['prevalence_general'].mean

print("✓ Parameters extracted")

# Save the base case
base_case_data = {
    'ai_results': ai_eff0_psa_results,
    'non_ai_results': non_ai_psa_results,
    'model_params': model_params_dict,
    'variable_names': trace_variable_names,
    'original_prevalence': original_prevalence
}

# Save to file
filepath = Path('../data/base_case_human_cost_240.pkl')
filepath.parent.mkdir(parents=True, exist_ok=True)

with open(filepath, 'wb') as f:
    pickle.dump(base_case_data, f)

print(f"\n✓ Base case saved to {filepath}")
print(f"\nSaved data summary:")
print(f"  AI PSA iterations: {ai_eff0_psa_results['trace_tensor'].shape[0]:,}")
print(f"  Non-AI PSA iterations: {non_ai_psa_results['trace_tensor'].shape[0]:,}")
print(f"  Time horizon: {ai_eff0_psa_results['trace_tensor'].shape[1]} years")
print(f"  Variables tracked: {len(trace_variable_names)}")
print(f"  Base prevalence: {original_prevalence:.1%}")
print(f"  Human screening cost: €{HUMAN_SCREENING_COST:.2f}")
# Out:
# Extracting model parameters...
# ✓ Parameters extracted
#
# ✓ Base case saved to ..\data\base_case_human_cost_240.pkl
#
# Saved data summary:
#   AI PSA iterations: 5,000
#   Non-AI PSA iterations: 5,000
#   Time horizon: 31 years
#   Variables tracked: 28
#   Base prevalence: 5.0%
#   Human screening cost: €240.20

# %% [markdown]
# ## 18. Conclusions

# %%
# Get 10-year results for conclusions
res_10y = comprehensive_results['10_years']['summary']

print("\n" + "="*100)
print("BASE CASE CONCLUSIONS (10-YEAR HORIZON)")
print(f"Human Screening Cost: €{HUMAN_SCREENING_COST:.2f}")
print("="*100)

print(f"\n1. COST-EFFECTIVENESS")
print(f"   ICER: €{res_10y['icer_mean']:,.0f}/QALY")
if res_10y['icer_mean'] < 50000:
    print(f"   → AI screening is COST-EFFECTIVE at €50,000/QALY threshold")
elif res_10y['icer_mean'] < 100000:
    print(f"   → AI screening is POTENTIALLY COST-EFFECTIVE (between €50k-€100k/QALY)")
else:
    print(f"   → AI screening is NOT COST-EFFECTIVE at conventional thresholds")

print(f"\n2. INCREMENTAL OUTCOMES")
print(f"   Additional cost: €{res_10y['incremental_cost_mean']:,.0f}")
print(f"   Additional QALYs: {res_10y['incremental_qaly_mean']:.4f}")

print(f"\n3. UNCERTAINTY")
print(f"   Probability cost-effective at €50k/QALY: {res_10y['prob_cost_effective_50k']:.1f}%")
if res_10y['prob_cost_effective_50k'] > 80:
    print(f"   → HIGH confidence in cost-effectiveness")
elif res_10y['prob_cost_effective_50k'] > 50:
    print(f"   → MODERATE confidence in cost-effectiveness")
else:
    print(f"   → LOW confidence in cost-effectiveness")

print(f"\n4. IMPACT OF UPDATED HUMAN SCREENING COST")
print(f"   Original cost: €{original_human_cost:.2f}")
print(f"   Updated cost: €{HUMAN_SCREENING_COST:.2f}")
print(f"   Increase: €{HUMAN_SCREENING_COST - original_human_cost:,.2f} (+{(HUMAN_SCREENING_COST/original_human_cost - 1)*100:.1f}%)")
print(f"   → Higher FP follow-up costs increase overall screening costs")

print(f"\n5. NEXT STEPS")
print(f"   → Conduct sensitivity analyses on key parameters")
print(f"   → Explore different time horizons and starting ages")
print(f"   → Evaluate budget impact and implementation considerations")

print("\n" + "="*100)
print("ANALYSIS COMPLETE")
print("="*100)
# Out:
# ====================================================================================================
# BASE CASE CONCLUSIONS (10-YEAR HORIZON)
# Human Screening Cost: €240.20
# ====================================================================================================
#
# 1. COST-EFFECTIVENESS
#    ICER: €-2,076/QALY
#    → AI screening is COST-EFFECTIVE at €50,000/QALY threshold
#
# 2. INCREMENTAL OUTCOMES
#    Additional cost: €-1,293
#    Additional QALYs: 0.2223
#
# 3. UNCERTAINTY
#    Probability cost-effective at €50k/QALY: 87.8%
#    → HIGH confidence in cost-effectiveness
#
# 4. IMPACT OF UPDATED HUMAN SCREENING COST
#    Original cost: €215.00
#    Updated cost: €240.20
#    Increase: €25.20 (+11.7%)
#    → Higher FP follow-up costs increase overall screening costs
#
# 5. NEXT STEPS
#    → Conduct sensitivity analyses on key parameters
#    → Explore different time horizons and starting ages
#    → Evaluate budget impact and implementation considerations
#
# ====================================================================================================
# ANALYSIS COMPLETE
# ====================================================================================================
